# %%
import pandas as pd
import numpy as np
import json
import os
from ast import literal_eval
from collections import defaultdict

from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from nltk import word_tokenize

# %%
#load tweets and put them into a single list
base_path = 'D...'
all_data = []
for filename in os.listdir(base_path):
    if filename.endswith('.json'):
        with open(os.path.join(base_path, filename)) as f:
            myjson = json.loads(f.read())
            all_data.extend(myjson)
            print('Loaded {} JSON Objects'.format(len(myjson)))
# Out:
# Loaded 86 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 92 JSON Objects
# Loaded 90 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 87 JSON Objects
# Loaded 93 JSON Objects
# Loaded 91 JSON Objects
# Loaded 89 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 98 JSON Objects
# Loaded 89 JSON Objects
# Loaded 90 JSON Objects
# Loaded 94 JSON Objects
# Loaded 98 JSON Objects
# Loaded 93 JSON Objects
# Loaded 96 JSON Objects
# Loaded 91 JSON Objects
# Loaded 95 JSON Objects
# Loaded 99 JSON Objects
# Loaded 90 JSON Objects
# Loaded 94 JSON Objects
# Loaded 89 JSON Objects
# Loaded 93 JSON Objects
# Loaded 98 JSON Objects
# Loaded 97 JSON Objects
# Loaded 92 JSON Objects
# Loaded 87 JSON Objects
# Loaded 90 JSON Objects
# Loaded 94 JSON Objects
# Loaded 85 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 89 JSON Objects
# Loaded 94 JSON Objects
# Loaded 91 JSON Objects
# Loaded 92 JSON Objects
# Loaded 85 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 90 JSON Objects
# Loaded 92 JSON Objects
# Loaded 98 JSON Objects
# Loaded 97 JSON Objects
# Loaded 90 JSON Objects
# Loaded 91 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 96 JSON Objects
# Loaded 90 JSON Objects
# Loaded 97 JSON Objects
# Loaded 91 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 89 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 90 JSON Objects
# Loaded 95 JSON Objects
# Loaded 90 JSON Objects
# Loaded 88 JSON Objects
# Loaded 89 JSON Objects
# Loaded 92 JSON Objects
# Loaded 90 JSON Objects
# Loaded 95 JSON Objects
# Loaded 96 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 98 JSON Objects
# Loaded 91 JSON Objects
# Loaded 94 JSON Objects
# Loaded 96 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 90 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 97 JSON Objects
# Loaded 96 JSON Objects
# Loaded 89 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 92 JSON Objects
# Loaded 92 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 91 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 90 JSON Objects
# Loaded 91 JSON Objects
# Loaded 96 JSON Objects
# Loaded 87 JSON Objects
# Loaded 88 JSON Objects
# Loaded 90 JSON Objects
# Loaded 96 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 88 JSON Objects
# Loaded 95 JSON Objects
# Loaded 89 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 97 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 88 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 91 JSON Objects
# Loaded 92 JSON Objects
# Loaded 90 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 91 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 97 JSON Objects
# Loaded 91 JSON Objects
# Loaded 92 JSON Objects
# Loaded 96 JSON Objects
# Loaded 86 JSON Objects
# Loaded 95 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 89 JSON Objects
# Loaded 96 JSON Objects
# Loaded 96 JSON Objects
# Loaded 89 JSON Objects
# Loaded 96 JSON Objects
# Loaded 95 JSON Objects
# Loaded 95 JSON Objects
# Loaded 96 JSON Objects
# Loaded 96 JSON Objects
# Loaded 91 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 95 JSON Objects
# Loaded 91 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 94 JSON Objects
# Loaded 93 JSON Objects
# Loaded 98 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 91 JSON Objects
# Loaded 93 JSON Objects
# Loaded 96 JSON Objects
# Loaded 89 JSON Objects
# Loaded 96 JSON Objects
# Loaded 97 JSON Objects
# Loaded 96 JSON Objects
# Loaded 97 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 98 JSON Objects
# Loaded 96 JSON Objects
# Loaded 92 JSON Objects
# Loaded 91 JSON Objects
# Loaded 89 JSON Objects
# Loaded 96 JSON Objects
# Loaded 96 JSON Objects
# Loaded 98 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 90 JSON Objects
# Loaded 98 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 93 JSON Objects
# Loaded 98 JSON Objects
# Loaded 90 JSON Objects
# Loaded 91 JSON Objects
# Loaded 90 JSON Objects
# Loaded 97 JSON Objects
# Loaded 95 JSON Objects
# Loaded 98 JSON Objects
# Loaded 97 JSON Objects
# Loaded 97 JSON Objects
# Loaded 96 JSON Objects
# Loaded 97 JSON Objects
# Loaded 89 JSON Objects
# Loaded 91 JSON Objects
# Loaded 96 JSON Objects
# Loaded 98 JSON Objects
# Loaded 99 JSON Objects
# Loaded 98 JSON Objects
# Loaded 94 JSON Objects
# Loaded 93 JSON Objects
# Loaded 96 JSON Objects
# Loaded 92 JSON Objects
# Loaded 92 JSON Objects
# Loaded 90 JSON Objects
# Loaded 94 JSON Objects
# Loaded 89 JSON Objects
# Loaded 96 JSON Objects
# Loaded 97 JSON Objects
# Loaded 96 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 90 JSON Objects
# Loaded 98 JSON Objects
# Loaded 97 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 96 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 96 JSON Objects
# Loaded 93 JSON Objects
# Loaded 90 JSON Objects
# Loaded 96 JSON Objects
# Loaded 89 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 95 JSON Objects
# Loaded 97 JSON Objects
# Loaded 94 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 96 JSON Objects
# Loaded 96 JSON Objects
# Loaded 98 JSON Objects
# Loaded 90 JSON Objects
# Loaded 93 JSON Objects
# Loaded 96 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 96 JSON Objects
# Loaded 98 JSON Objects
# Loaded 91 JSON Objects
# Loaded 97 JSON Objects
# Loaded 96 JSON Objects
# Loaded 95 JSON Objects
# Loaded 98 JSON Objects
# Loaded 96 JSON Objects
# Loaded 98 JSON Objects
# Loaded 95 JSON Objects
# Loaded 97 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 90 JSON Objects
# Loaded 93 JSON Objects
# Loaded 97 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 97 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 96 JSON Objects
# Loaded 97 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 97 JSON Objects
# Loaded 96 JSON Objects
# Loaded 95 JSON Objects
# Loaded 91 JSON Objects
# Loaded 90 JSON Objects
# Loaded 92 JSON Objects
# Loaded 91 JSON Objects
# Loaded 95 JSON Objects
# Loaded 90 JSON Objects
# Loaded 99 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 97 JSON Objects
# Loaded 98 JSON Objects
# Loaded 92 JSON Objects
# Loaded 98 JSON Objects
# Loaded 91 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 96 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 97 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 91 JSON Objects
# Loaded 94 JSON Objects
# Loaded 92 JSON Objects
# Loaded 90 JSON Objects
# Loaded 98 JSON Objects
# Loaded 97 JSON Objects
# Loaded 91 JSON Objects
# Loaded 97 JSON Objects
# Loaded 97 JSON Objects
# Loaded 69 JSON Objects
# Loaded 78 JSON Objects
# Loaded 89 JSON Objects
# Loaded 97 JSON Objects
# Loaded 97 JSON Objects
# Loaded 94 JSON Objects
# Loaded 89 JSON Objects
# Loaded 97 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 91 JSON Objects
# Loaded 91 JSON Objects
# Loaded 97 JSON Objects
# Loaded 93 JSON Objects
# Loaded 91 JSON Objects
# Loaded 89 JSON Objects
# Loaded 99 JSON Objects
# Loaded 98 JSON Objects
# Loaded 87 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 97 JSON Objects
# Loaded 95 JSON Objects
# Loaded 97 JSON Objects
# Loaded 93 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 89 JSON Objects
# Loaded 95 JSON Objects
# Loaded 91 JSON Objects
# Loaded 91 JSON Objects
# Loaded 91 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 97 JSON Objects
# Loaded 93 JSON Objects
# Loaded 91 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 89 JSON Objects
# Loaded 53 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 98 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 84 JSON Objects
# Loaded 91 JSON Objects
# Loaded 82 JSON Objects
# Loaded 94 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 95 JSON Objects
# Loaded 97 JSON Objects
# Loaded 90 JSON Objects
# Loaded 94 JSON Objects
# Loaded 89 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 96 JSON Objects
# Loaded 87 JSON Objects
# Loaded 90 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 92 JSON Objects
# Loaded 96 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 98 JSON Objects
# Loaded 94 JSON Objects
# Loaded 97 JSON Objects
# Loaded 91 JSON Objects
# Loaded 93 JSON Objects
# Loaded 98 JSON Objects
# Loaded 91 JSON Objects
# Loaded 93 JSON Objects
# Loaded 97 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 96 JSON Objects
# Loaded 91 JSON Objects
# Loaded 95 JSON Objects
# Loaded 98 JSON Objects
# Loaded 94 JSON Objects
# Loaded 96 JSON Objects
# Loaded 91 JSON Objects
# Loaded 94 JSON Objects
# Loaded 92 JSON Objects
# Loaded 96 JSON Objects
# Loaded 85 JSON Objects
# Loaded 94 JSON Objects
# Loaded 96 JSON Objects
# Loaded 98 JSON Objects
# Loaded 87 JSON Objects
# Loaded 94 JSON Objects
# Loaded 91 JSON Objects
# Loaded 94 JSON Objects
# Loaded 93 JSON Objects
# Loaded 89 JSON Objects
# Loaded 92 JSON Objects
# Loaded 85 JSON Objects
# Loaded 92 JSON Objects
# Loaded 94 JSON Objects
# Loaded 88 JSON Objects
# Loaded 96 JSON Objects
# Loaded 95 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 91 JSON Objects
# Loaded 93 JSON Objects
# Loaded 96 JSON Objects
# Loaded 91 JSON Objects
# Loaded 90 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 91 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 93 JSON Objects
# Loaded 98 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 89 JSON Objects
# Loaded 92 JSON Objects
# Loaded 96 JSON Objects
# Loaded 90 JSON Objects
# Loaded 95 JSON Objects
# Loaded 95 JSON Objects
# Loaded 90 JSON Objects
# Loaded 90 JSON Objects
# Loaded 89 JSON Objects
# Loaded 92 JSON Objects
# Loaded 96 JSON Objects
# Loaded 91 JSON Objects
# Loaded 92 JSON Objects
# Loaded 89 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 89 JSON Objects
# Loaded 92 JSON Objects
# Loaded 91 JSON Objects
# Loaded 91 JSON Objects
# Loaded 92 JSON Objects
# Loaded 92 JSON Objects
# Loaded 90 JSON Objects
# Loaded 88 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 91 JSON Objects
# Loaded 91 JSON Objects
# Loaded 95 JSON Objects
# Loaded 95 JSON Objects
# Loaded 88 JSON Objects
# Loaded 83 JSON Objects
# Loaded 88 JSON Objects
# Loaded 93 JSON Objects
# Loaded 97 JSON Objects
# Loaded 93 JSON Objects
# Loaded 88 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 96 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 94 JSON Objects
# Loaded 90 JSON Objects
# Loaded 96 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 91 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 96 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 94 JSON Objects
# Loaded 92 JSON Objects
# Loaded 92 JSON Objects
# Loaded 92 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 91 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 92 JSON Objects
# Loaded 92 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 91 JSON Objects
# Loaded 90 JSON Objects
# Loaded 90 JSON Objects
# Loaded 91 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 89 JSON Objects
# Loaded 90 JSON Objects
# Loaded 98 JSON Objects
# Loaded 91 JSON Objects
# Loaded 89 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 87 JSON Objects
# Loaded 95 JSON Objects
# Loaded 91 JSON Objects
# Loaded 94 JSON Objects
# Loaded 96 JSON Objects
# Loaded 92 JSON Objects
# Loaded 91 JSON Objects
# Loaded 94 JSON Objects
# Loaded 91 JSON Objects
# Loaded 97 JSON Objects
# Loaded 90 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 89 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 90 JSON Objects
# Loaded 88 JSON Objects
# Loaded 89 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 91 JSON Objects
# Loaded 88 JSON Objects
# Loaded 91 JSON Objects
# Loaded 88 JSON Objects
# Loaded 88 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 96 JSON Objects
# Loaded 96 JSON Objects
# Loaded 92 JSON Objects
# Loaded 96 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 90 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 89 JSON Objects
# Loaded 92 JSON Objects
# Loaded 81 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 87 JSON Objects
# Loaded 91 JSON Objects
# Loaded 94 JSON Objects
# Loaded 91 JSON Objects
# Loaded 92 JSON Objects
# Loaded 97 JSON Objects
# Loaded 94 JSON Objects
# Loaded 91 JSON Objects
# Loaded 92 JSON Objects
# Loaded 90 JSON Objects
# Loaded 94 JSON Objects
# Loaded 96 JSON Objects
# Loaded 95 JSON Objects
# Loaded 95 JSON Objects
# Loaded 95 JSON Objects
# Loaded 89 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 96 JSON Objects
# Loaded 95 JSON Objects
# Loaded 90 JSON Objects
# Loaded 93 JSON Objects
# Loaded 89 JSON Objects
# Loaded 92 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 88 JSON Objects
# Loaded 96 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 87 JSON Objects
# Loaded 97 JSON Objects
# Loaded 92 JSON Objects
# Loaded 88 JSON Objects
# Loaded 97 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 87 JSON Objects
# Loaded 92 JSON Objects
# Loaded 97 JSON Objects
# Loaded 91 JSON Objects
# Loaded 91 JSON Objects
# Loaded 93 JSON Objects
# Loaded 91 JSON Objects
# Loaded 92 JSON Objects
# Loaded 97 JSON Objects
# Loaded 92 JSON Objects
# Loaded 92 JSON Objects
# Loaded 92 JSON Objects
# Loaded 89 JSON Objects
# Loaded 89 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 91 JSON Objects
# Loaded 91 JSON Objects
# Loaded 89 JSON Objects
# Loaded 92 JSON Objects
# Loaded 94 JSON Objects
# Loaded 89 JSON Objects
# Loaded 93 JSON Objects
# Loaded 90 JSON Objects
# Loaded 92 JSON Objects
# Loaded 97 JSON Objects
# Loaded 91 JSON Objects
# Loaded 89 JSON Objects
# Loaded 94 JSON Objects
# Loaded 96 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 90 JSON Objects
# Loaded 95 JSON Objects
# Loaded 96 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 94 JSON Objects
# Loaded 97 JSON Objects
# Loaded 96 JSON Objects
# Loaded 91 JSON Objects
# Loaded 96 JSON Objects
# Loaded 98 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 91 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 90 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 97 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 96 JSON Objects
# Loaded 90 JSON Objects
# Loaded 97 JSON Objects
# Loaded 96 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 97 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 97 JSON Objects
# Loaded 91 JSON Objects
# Loaded 97 JSON Objects
# Loaded 94 JSON Objects
# Loaded 97 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 97 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 98 JSON Objects
# Loaded 92 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 90 JSON Objects
# Loaded 96 JSON Objects
# Loaded 93 JSON Objects
# Loaded 89 JSON Objects
# Loaded 97 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 97 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 87 JSON Objects
# Loaded 86 JSON Objects
# Loaded 94 JSON Objects
# Loaded 90 JSON Objects
# Loaded 86 JSON Objects
# Loaded 87 JSON Objects
# Loaded 88 JSON Objects
# Loaded 90 JSON Objects
# Loaded 91 JSON Objects
# Loaded 94 JSON Objects
# Loaded 91 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 88 JSON Objects
# Loaded 94 JSON Objects
# Loaded 90 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 96 JSON Objects
# Loaded 92 JSON Objects
# Loaded 94 JSON Objects
# Loaded 97 JSON Objects
# Loaded 88 JSON Objects
# Loaded 98 JSON Objects
# Loaded 94 JSON Objects
# Loaded 93 JSON Objects
# Loaded 91 JSON Objects
# Loaded 90 JSON Objects
# Loaded 92 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 90 JSON Objects
# Loaded 99 JSON Objects
# Loaded 89 JSON Objects
# Loaded 95 JSON Objects
# Loaded 98 JSON Objects
# Loaded 96 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 96 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 96 JSON Objects
# Loaded 97 JSON Objects
# Loaded 91 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 88 JSON Objects
# Loaded 94 JSON Objects
# Loaded 91 JSON Objects
# Loaded 92 JSON Objects
# Loaded 91 JSON Objects
# Loaded 97 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 91 JSON Objects
# Loaded 97 JSON Objects
# Loaded 88 JSON Objects
# Loaded 89 JSON Objects
# Loaded 91 JSON Objects
# Loaded 94 JSON Objects
# Loaded 97 JSON Objects
# Loaded 90 JSON Objects
# Loaded 94 JSON Objects
# Loaded 90 JSON Objects
# Loaded 93 JSON Objects
# Loaded 91 JSON Objects
# Loaded 97 JSON Objects
# Loaded 92 JSON Objects
# Loaded 91 JSON Objects
# Loaded 94 JSON Objects
# Loaded 97 JSON Objects
# Loaded 90 JSON Objects
# Loaded 96 JSON Objects
# Loaded 95 JSON Objects
# Loaded 90 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 98 JSON Objects
# Loaded 95 JSON Objects
# Loaded 89 JSON Objects
# Loaded 94 JSON Objects
# Loaded 92 JSON Objects
# Loaded 91 JSON Objects
# Loaded 99 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 90 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 91 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 98 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 96 JSON Objects
# Loaded 89 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 96 JSON Objects
# Loaded 91 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 91 JSON Objects
# Loaded 96 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 94 JSON Objects
# Loaded 90 JSON Objects
# Loaded 94 JSON Objects
# Loaded 92 JSON Objects
# Loaded 91 JSON Objects
# Loaded 96 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 91 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 93 JSON Objects
# Loaded 97 JSON Objects
# Loaded 94 JSON Objects
# Loaded 92 JSON Objects
# Loaded 90 JSON Objects
# Loaded 94 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 91 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 92 JSON Objects
# Loaded 94 JSON Objects
# Loaded 91 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 98 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 98 JSON Objects
# Loaded 96 JSON Objects
# Loaded 99 JSON Objects
# Loaded 94 JSON Objects
# Loaded 92 JSON Objects
# Loaded 92 JSON Objects
# Loaded 97 JSON Objects
# Loaded 95 JSON Objects
# Loaded 97 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 98 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 90 JSON Objects
# Loaded 94 JSON Objects
# Loaded 93 JSON Objects
# Loaded 97 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 91 JSON Objects
# Loaded 94 JSON Objects
# Loaded 92 JSON Objects
# Loaded 90 JSON Objects
# Loaded 94 JSON Objects
# Loaded 88 JSON Objects
# Loaded 97 JSON Objects
# Loaded 90 JSON Objects
# Loaded 96 JSON Objects
# Loaded 97 JSON Objects
# Loaded 95 JSON Objects
# Loaded 97 JSON Objects
# Loaded 97 JSON Objects
# Loaded 99 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 89 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 97 JSON Objects
# Loaded 96 JSON Objects
# Loaded 97 JSON Objects
# Loaded 96 JSON Objects
# Loaded 98 JSON Objects
# Loaded 95 JSON Objects
# Loaded 97 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 92 JSON Objects
# Loaded 97 JSON Objects
# Loaded 96 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 96 JSON Objects
# Loaded 99 JSON Objects
# Loaded 94 JSON Objects
# Loaded 98 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 99 JSON Objects
# Loaded 95 JSON Objects
# Loaded 97 JSON Objects
# Loaded 94 JSON Objects
# Loaded 91 JSON Objects
# Loaded 96 JSON Objects
# Loaded 95 JSON Objects
# Loaded 89 JSON Objects
# Loaded 96 JSON Objects
# Loaded 96 JSON Objects
# Loaded 68 JSON Objects
# Loaded 94 JSON Objects
# Loaded 96 JSON Objects
# Loaded 96 JSON Objects
# Loaded 96 JSON Objects
# Loaded 96 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 86 JSON Objects
# Loaded 95 JSON Objects
# Loaded 90 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 92 JSON Objects
# Loaded 94 JSON Objects
# Loaded 98 JSON Objects
# Loaded 97 JSON Objects
# Loaded 96 JSON Objects
# Loaded 90 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 97 JSON Objects
# Loaded 90 JSON Objects
# Loaded 87 JSON Objects
# Loaded 98 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 91 JSON Objects
# Loaded 97 JSON Objects
# Loaded 95 JSON Objects
# Loaded 88 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 91 JSON Objects
# Loaded 92 JSON Objects
# Loaded 92 JSON Objects
# Loaded 86 JSON Objects
# Loaded 92 JSON Objects
# Loaded 97 JSON Objects
# Loaded 92 JSON Objects
# Loaded 97 JSON Objects
# Loaded 97 JSON Objects
# Loaded 93 JSON Objects
# Loaded 89 JSON Objects
# Loaded 93 JSON Objects
# Loaded 90 JSON Objects
# Loaded 90 JSON Objects
# Loaded 90 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 91 JSON Objects
# Loaded 94 JSON Objects
# Loaded 90 JSON Objects
# Loaded 91 JSON Objects
# Loaded 96 JSON Objects
# Loaded 96 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 91 JSON Objects
# Loaded 94 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 91 JSON Objects
# Loaded 91 JSON Objects
# Loaded 93 JSON Objects
# Loaded 85 JSON Objects
# Loaded 90 JSON Objects
# Loaded 94 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 91 JSON Objects
# Loaded 96 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 96 JSON Objects
# Loaded 96 JSON Objects
# Loaded 96 JSON Objects
# Loaded 89 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 97 JSON Objects
# Loaded 86 JSON Objects
# Loaded 97 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 92 JSON Objects
# Loaded 90 JSON Objects
# Loaded 91 JSON Objects
# Loaded 97 JSON Objects
# Loaded 95 JSON Objects
# Loaded 96 JSON Objects
# Loaded 88 JSON Objects
# Loaded 90 JSON Objects
# Loaded 94 JSON Objects
# Loaded 97 JSON Objects
# Loaded 93 JSON Objects
# Loaded 91 JSON Objects
# Loaded 97 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 89 JSON Objects
# Loaded 89 JSON Objects
# Loaded 94 JSON Objects
# Loaded 92 JSON Objects
# Loaded 90 JSON Objects
# Loaded 94 JSON Objects
# Loaded 92 JSON Objects
# Loaded 94 JSON Objects
# Loaded 96 JSON Objects
# Loaded 92 JSON Objects
# Loaded 89 JSON Objects
# Loaded 94 JSON Objects
# Loaded 97 JSON Objects
# Loaded 94 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 95 JSON Objects
# Loaded 90 JSON Objects
# Loaded 95 JSON Objects
# Loaded 98 JSON Objects
# Loaded 77 JSON Objects
# Loaded 90 JSON Objects
# Loaded 95 JSON Objects
# Loaded 90 JSON Objects
# Loaded 92 JSON Objects
# Loaded 89 JSON Objects
# Loaded 95 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 91 JSON Objects
# Loaded 95 JSON Objects
# Loaded 97 JSON Objects
# Loaded 96 JSON Objects
# Loaded 89 JSON Objects
# Loaded 92 JSON Objects
# Loaded 97 JSON Objects
# Loaded 92 JSON Objects
# Loaded 89 JSON Objects
# Loaded 91 JSON Objects
# Loaded 97 JSON Objects
# Loaded 96 JSON Objects
# Loaded 98 JSON Objects
# Loaded 94 JSON Objects
# Loaded 96 JSON Objects
# Loaded 96 JSON Objects
# Loaded 92 JSON Objects
# Loaded 97 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 92 JSON Objects
# Loaded 97 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 91 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 91 JSON Objects
# Loaded 88 JSON Objects
# Loaded 94 JSON Objects
# Loaded 90 JSON Objects
# Loaded 96 JSON Objects
# Loaded 90 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 88 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 97 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 87 JSON Objects
# Loaded 97 JSON Objects
# Loaded 93 JSON Objects
# Loaded 89 JSON Objects
# Loaded 95 JSON Objects
# Loaded 96 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 87 JSON Objects
# Loaded 89 JSON Objects
# Loaded 91 JSON Objects
# Loaded 87 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 89 JSON Objects
# Loaded 96 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 97 JSON Objects
# Loaded 91 JSON Objects
# Loaded 97 JSON Objects
# Loaded 96 JSON Objects
# Loaded 97 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 90 JSON Objects
# Loaded 95 JSON Objects
# Loaded 91 JSON Objects
# Loaded 96 JSON Objects
# Loaded 93 JSON Objects
# Loaded 89 JSON Objects
# Loaded 94 JSON Objects
# Loaded 97 JSON Objects
# Loaded 93 JSON Objects
# Loaded 89 JSON Objects
# Loaded 91 JSON Objects
# Loaded 93 JSON Objects
# Loaded 90 JSON Objects
# Loaded 97 JSON Objects
# Loaded 96 JSON Objects
# Loaded 98 JSON Objects
# Loaded 93 JSON Objects
# Loaded 100 JSON Objects
# Loaded 92 JSON Objects
# Loaded 88 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 91 JSON Objects
# Loaded 96 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 89 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 92 JSON Objects
# Loaded 96 JSON Objects
# Loaded 97 JSON Objects
# Loaded 96 JSON Objects
# Loaded 89 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 95 JSON Objects
# Loaded 91 JSON Objects
# Loaded 97 JSON Objects
# Loaded 94 JSON Objects
# Loaded 98 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 96 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 96 JSON Objects
# Loaded 91 JSON Objects
# Loaded 94 JSON Objects
# Loaded 89 JSON Objects
# Loaded 88 JSON Objects
# Loaded 94 JSON Objects
# Loaded 92 JSON Objects
# Loaded 91 JSON Objects
# Loaded 97 JSON Objects
# Loaded 92 JSON Objects
# Loaded 89 JSON Objects
# Loaded 90 JSON Objects
# Loaded 91 JSON Objects
# Loaded 95 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 96 JSON Objects
# Loaded 96 JSON Objects
# Loaded 92 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 89 JSON Objects
# Loaded 82 JSON Objects
# Loaded 92 JSON Objects
# Loaded 88 JSON Objects
# Loaded 88 JSON Objects
# Loaded 85 JSON Objects
# Loaded 96 JSON Objects
# Loaded 90 JSON Objects
# Loaded 94 JSON Objects
# Loaded 90 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 97 JSON Objects
# Loaded 91 JSON Objects
# Loaded 94 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 84 JSON Objects
# Loaded 95 JSON Objects
# Loaded 91 JSON Objects
# Loaded 96 JSON Objects
# Loaded 92 JSON Objects
# Loaded 91 JSON Objects
# Loaded 90 JSON Objects
# Loaded 88 JSON Objects
# Loaded 91 JSON Objects
# Loaded 94 JSON Objects
# Loaded 92 JSON Objects
# Loaded 92 JSON Objects
# Loaded 91 JSON Objects
# Loaded 91 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 92 JSON Objects
# Loaded 91 JSON Objects
# Loaded 90 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 91 JSON Objects
# Loaded 92 JSON Objects
# Loaded 86 JSON Objects
# Loaded 91 JSON Objects
# Loaded 94 JSON Objects
# Loaded 90 JSON Objects
# Loaded 97 JSON Objects
# Loaded 94 JSON Objects
# Loaded 96 JSON Objects
# Loaded 97 JSON Objects
# Loaded 97 JSON Objects
# Loaded 97 JSON Objects
# Loaded 97 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 96 JSON Objects
# Loaded 97 JSON Objects
# Loaded 97 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 96 JSON Objects
# Loaded 92 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 87 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 97 JSON Objects
# Loaded 95 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 93 JSON Objects
# Loaded 96 JSON Objects
# Loaded 98 JSON Objects
# Loaded 97 JSON Objects
# Loaded 95 JSON Objects
# Loaded 96 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 98 JSON Objects
# Loaded 96 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 99 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 97 JSON Objects
# Loaded 96 JSON Objects
# Loaded 95 JSON Objects
# Loaded 98 JSON Objects
# Loaded 95 JSON Objects
# Loaded 91 JSON Objects
# Loaded 98 JSON Objects
# Loaded 96 JSON Objects
# Loaded 90 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 96 JSON Objects
# Loaded 93 JSON Objects
# Loaded 90 JSON Objects
# Loaded 94 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 86 JSON Objects
# Loaded 94 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 89 JSON Objects
# Loaded 92 JSON Objects
# Loaded 96 JSON Objects
# Loaded 97 JSON Objects
# Loaded 89 JSON Objects
# Loaded 94 JSON Objects
# Loaded 91 JSON Objects
# Loaded 94 JSON Objects
# Loaded 97 JSON Objects
# Loaded 90 JSON Objects
# Loaded 92 JSON Objects
# Loaded 91 JSON Objects
# Loaded 96 JSON Objects
# Loaded 93 JSON Objects
# Loaded 90 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 99 JSON Objects
# Loaded 94 JSON Objects
# Loaded 97 JSON Objects
# Loaded 91 JSON Objects
# Loaded 91 JSON Objects
# Loaded 89 JSON Objects
# Loaded 93 JSON Objects
# Loaded 97 JSON Objects
# Loaded 95 JSON Objects
# Loaded 96 JSON Objects
# Loaded 92 JSON Objects
# Loaded 97 JSON Objects
# Loaded 96 JSON Objects
# Loaded 96 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 91 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 96 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 89 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 97 JSON Objects
# Loaded 98 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 96 JSON Objects
# Loaded 96 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 97 JSON Objects
# Loaded 89 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 97 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 91 JSON Objects
# Loaded 90 JSON Objects
# Loaded 94 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 96 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 91 JSON Objects
# Loaded 87 JSON Objects
# Loaded 91 JSON Objects
# Loaded 89 JSON Objects
# Loaded 92 JSON Objects
# Loaded 87 JSON Objects
# Loaded 87 JSON Objects
# Loaded 87 JSON Objects
# Loaded 92 JSON Objects
# Loaded 90 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 86 JSON Objects
# Loaded 93 JSON Objects
# Loaded 91 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 89 JSON Objects
# Loaded 94 JSON Objects
# Loaded 87 JSON Objects
# Loaded 96 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 91 JSON Objects
# Loaded 91 JSON Objects
# Loaded 88 JSON Objects
# Loaded 94 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 88 JSON Objects
# Loaded 94 JSON Objects
# Loaded 90 JSON Objects
# Loaded 90 JSON Objects
# Loaded 94 JSON Objects
# Loaded 92 JSON Objects
# Loaded 87 JSON Objects
# Loaded 92 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 90 JSON Objects
# Loaded 96 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 89 JSON Objects
# Loaded 93 JSON Objects
# Loaded 90 JSON Objects
# Loaded 96 JSON Objects
# Loaded 96 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 95 JSON Objects
# Loaded 96 JSON Objects
# Loaded 92 JSON Objects
# Loaded 92 JSON Objects
# Loaded 88 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 96 JSON Objects
# Loaded 98 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 96 JSON Objects
# Loaded 96 JSON Objects
# Loaded 90 JSON Objects
# Loaded 96 JSON Objects
# Loaded 92 JSON Objects
# Loaded 89 JSON Objects
# Loaded 94 JSON Objects
# Loaded 92 JSON Objects
# Loaded 96 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 97 JSON Objects
# Loaded 91 JSON Objects
# Loaded 95 JSON Objects
# Loaded 97 JSON Objects
# Loaded 97 JSON Objects
# Loaded 97 JSON Objects
# Loaded 99 JSON Objects
# Loaded 92 JSON Objects
# Loaded 90 JSON Objects
# Loaded 89 JSON Objects
# Loaded 91 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 88 JSON Objects
# Loaded 98 JSON Objects
# Loaded 95 JSON Objects
# Loaded 89 JSON Objects
# Loaded 93 JSON Objects
# Loaded 97 JSON Objects
# Loaded 92 JSON Objects
# Loaded 96 JSON Objects
# Loaded 96 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 100 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 93 JSON Objects
# Loaded 90 JSON Objects
# Loaded 89 JSON Objects
# Loaded 91 JSON Objects
# Loaded 93 JSON Objects
# Loaded 96 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 90 JSON Objects
# Loaded 93 JSON Objects
# Loaded 90 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 91 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 88 JSON Objects
# Loaded 94 JSON Objects
# Loaded 92 JSON Objects
# Loaded 92 JSON Objects
# Loaded 92 JSON Objects
# Loaded 99 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 94 JSON Objects
# Loaded 96 JSON Objects
# Loaded 95 JSON Objects
# Loaded 90 JSON Objects
# Loaded 84 JSON Objects
# Loaded 91 JSON Objects
# Loaded 98 JSON Objects
# Loaded 92 JSON Objects
# Loaded 96 JSON Objects
# Loaded 95 JSON Objects
# Loaded 91 JSON Objects
# Loaded 89 JSON Objects
# Loaded 91 JSON Objects
# Loaded 96 JSON Objects
# Loaded 99 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 97 JSON Objects
# Loaded 96 JSON Objects
# Loaded 96 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 89 JSON Objects
# Loaded 94 JSON Objects
# Loaded 88 JSON Objects
# Loaded 91 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 86 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 90 JSON Objects
# Loaded 91 JSON Objects
# Loaded 89 JSON Objects
# Loaded 86 JSON Objects
# Loaded 86 JSON Objects
# Loaded 97 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 88 JSON Objects
# Loaded 92 JSON Objects
# Loaded 96 JSON Objects
# Loaded 91 JSON Objects
# Loaded 89 JSON Objects
# Loaded 91 JSON Objects
# Loaded 95 JSON Objects
# Loaded 96 JSON Objects
# Loaded 89 JSON Objects
# Loaded 87 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 96 JSON Objects
# Loaded 93 JSON Objects
# Loaded 97 JSON Objects
# Loaded 90 JSON Objects
# Loaded 88 JSON Objects
# Loaded 93 JSON Objects
# Loaded 90 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 96 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 89 JSON Objects
# Loaded 91 JSON Objects
# Loaded 88 JSON Objects
# Loaded 95 JSON Objects
# Loaded 96 JSON Objects
# Loaded 96 JSON Objects
# Loaded 96 JSON Objects
# Loaded 89 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 90 JSON Objects
# Loaded 87 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 85 JSON Objects
# Loaded 94 JSON Objects
# Loaded 80 JSON Objects
# Loaded 90 JSON Objects
# Loaded 94 JSON Objects
# Loaded 90 JSON Objects
# Loaded 90 JSON Objects
# Loaded 95 JSON Objects
# Loaded 91 JSON Objects
# Loaded 91 JSON Objects
# Loaded 90 JSON Objects
# Loaded 83 JSON Objects
# Loaded 93 JSON Objects
# Loaded 90 JSON Objects
# Loaded 90 JSON Objects
# Loaded 87 JSON Objects
# Loaded 95 JSON Objects
# Loaded 95 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 95 JSON Objects
# Loaded 99 JSON Objects
# Loaded 97 JSON Objects
# Loaded 91 JSON Objects
# Loaded 94 JSON Objects
# Loaded 88 JSON Objects
# Loaded 95 JSON Objects
# Loaded 91 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 95 JSON Objects
# Loaded 91 JSON Objects
# Loaded 85 JSON Objects
# Loaded 91 JSON Objects
# Loaded 91 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 88 JSON Objects
# Loaded 90 JSON Objects
# Loaded 90 JSON Objects
# Loaded 98 JSON Objects
# Loaded 97 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 91 JSON Objects
# Loaded 99 JSON Objects
# Loaded 90 JSON Objects
# Loaded 95 JSON Objects
# Loaded 96 JSON Objects
# Loaded 89 JSON Objects
# Loaded 94 JSON Objects
# Loaded 96 JSON Objects
# Loaded 97 JSON Objects
# Loaded 94 JSON Objects
# Loaded 96 JSON Objects
# Loaded 93 JSON Objects
# Loaded 96 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 96 JSON Objects
# Loaded 98 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 96 JSON Objects
# Loaded 97 JSON Objects
# Loaded 92 JSON Objects
# Loaded 92 JSON Objects
# Loaded 89 JSON Objects
# Loaded 90 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 95 JSON Objects
# Loaded 95 JSON Objects
# Loaded 91 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 97 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 93 JSON Objects
# Loaded 96 JSON Objects
# Loaded 90 JSON Objects
# Loaded 83 JSON Objects
# Loaded 98 JSON Objects
# Loaded 95 JSON Objects
# Loaded 86 JSON Objects
# Loaded 96 JSON Objects
# Loaded 91 JSON Objects
# Loaded 97 JSON Objects
# Loaded 93 JSON Objects
# Loaded 96 JSON Objects
# Loaded 95 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 96 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 97 JSON Objects
# Loaded 98 JSON Objects
# Loaded 94 JSON Objects
# Loaded 93 JSON Objects
# Loaded 89 JSON Objects
# Loaded 94 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 98 JSON Objects
# Loaded 92 JSON Objects
# Loaded 91 JSON Objects
# Loaded 91 JSON Objects
# Loaded 94 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 97 JSON Objects
# Loaded 93 JSON Objects
# Loaded 91 JSON Objects
# Loaded 90 JSON Objects
# Loaded 92 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 97 JSON Objects
# Loaded 89 JSON Objects
# Loaded 92 JSON Objects
# Loaded 94 JSON Objects
# Loaded 92 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 91 JSON Objects
# Loaded 90 JSON Objects
# Loaded 93 JSON Objects
# Loaded 89 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 84 JSON Objects
# Loaded 92 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 89 JSON Objects
# Loaded 94 JSON Objects
# Loaded 90 JSON Objects
# Loaded 86 JSON Objects
# Loaded 90 JSON Objects
# Loaded 87 JSON Objects
# Loaded 92 JSON Objects
# Loaded 91 JSON Objects
# Loaded 96 JSON Objects
# Loaded 90 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 90 JSON Objects
# Loaded 90 JSON Objects
# Loaded 94 JSON Objects
# Loaded 86 JSON Objects
# Loaded 96 JSON Objects
# Loaded 98 JSON Objects
# Loaded 94 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 91 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 89 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 96 JSON Objects
# Loaded 96 JSON Objects
# Loaded 96 JSON Objects
# Loaded 95 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 100 JSON Objects
# Loaded 98 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 94 JSON Objects
# Loaded 97 JSON Objects
# Loaded 98 JSON Objects
# Loaded 98 JSON Objects
# Loaded 98 JSON Objects
# Loaded 94 JSON Objects
# Loaded 97 JSON Objects
# Loaded 99 JSON Objects
# Loaded 97 JSON Objects
# Loaded 92 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 91 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 91 JSON Objects
# Loaded 97 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 97 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 90 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 87 JSON Objects
# Loaded 94 JSON Objects
# Loaded 87 JSON Objects
# Loaded 94 JSON Objects
# Loaded 89 JSON Objects
# Loaded 92 JSON Objects
# Loaded 89 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 89 JSON Objects
# Loaded 96 JSON Objects
# Loaded 92 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 99 JSON Objects
# Loaded 94 JSON Objects
# Loaded 97 JSON Objects
# Loaded 96 JSON Objects
# Loaded 95 JSON Objects
# Loaded 90 JSON Objects
# Loaded 93 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 97 JSON Objects
# Loaded 93 JSON Objects
# Loaded 96 JSON Objects
# Loaded 91 JSON Objects
# Loaded 96 JSON Objects
# Loaded 92 JSON Objects
# Loaded 92 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 97 JSON Objects
# Loaded 98 JSON Objects
# Loaded 91 JSON Objects
# Loaded 91 JSON Objects
# Loaded 90 JSON Objects
# Loaded 96 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 92 JSON Objects
# Loaded 97 JSON Objects
# Loaded 95 JSON Objects
# Loaded 90 JSON Objects
# Loaded 93 JSON Objects
# Loaded 90 JSON Objects
# Loaded 90 JSON Objects
# Loaded 92 JSON Objects
# Loaded 90 JSON Objects
# Loaded 89 JSON Objects
# Loaded 88 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 96 JSON Objects
# Loaded 90 JSON Objects
# Loaded 93 JSON Objects
# Loaded 97 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 91 JSON Objects
# Loaded 95 JSON Objects
# Loaded 90 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 97 JSON Objects
# Loaded 94 JSON Objects
# Loaded 90 JSON Objects
# Loaded 91 JSON Objects
# Loaded 89 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 89 JSON Objects
# Loaded 96 JSON Objects
# Loaded 92 JSON Objects
# Loaded 91 JSON Objects
# Loaded 94 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 90 JSON Objects
# Loaded 95 JSON Objects
# Loaded 96 JSON Objects
# Loaded 91 JSON Objects
# Loaded 89 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 93 JSON Objects
# Loaded 96 JSON Objects
# Loaded 91 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 95 JSON Objects
# Loaded 97 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 86 JSON Objects
# Loaded 91 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 96 JSON Objects
# Loaded 90 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 96 JSON Objects
# Loaded 93 JSON Objects
# Loaded 98 JSON Objects
# Loaded 99 JSON Objects
# Loaded 92 JSON Objects
# Loaded 97 JSON Objects
# Loaded 91 JSON Objects
# Loaded 97 JSON Objects
# Loaded 89 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 88 JSON Objects
# Loaded 92 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 96 JSON Objects
# ...
# Loaded 88 JSON Objects
# Loaded 82 JSON Objects
# Loaded 87 JSON Objects
# Loaded 88 JSON Objects
# Loaded 99 JSON Objects
# Loaded 91 JSON Objects
# Loaded 91 JSON Objects
# Loaded 87 JSON Objects
# Loaded 86 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 89 JSON Objects
# Loaded 93 JSON Objects
# Loaded 96 JSON Objects
# Loaded 96 JSON Objects
# Loaded 93 JSON Objects
# Loaded 87 JSON Objects
# Loaded 87 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 92 JSON Objects
# Loaded 97 JSON Objects
# Loaded 87 JSON Objects
# Loaded 90 JSON Objects
# Loaded 90 JSON Objects
# Loaded 92 JSON Objects
# Loaded 92 JSON Objects
# Loaded 89 JSON Objects
# Loaded 94 JSON Objects
# Loaded 86 JSON Objects
# Loaded 91 JSON Objects
# Loaded 97 JSON Objects
# Loaded 92 JSON Objects
# Loaded 94 JSON Objects
# Loaded 90 JSON Objects
# Loaded 96 JSON Objects
# Loaded 88 JSON Objects
# Loaded 90 JSON Objects
# Loaded 95 JSON Objects
# Loaded 90 JSON Objects
# Loaded 90 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 89 JSON Objects
# Loaded 85 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 97 JSON Objects
# Loaded 92 JSON Objects
# Loaded 92 JSON Objects
# Loaded 91 JSON Objects
# Loaded 91 JSON Objects
# Loaded 92 JSON Objects
# Loaded 92 JSON Objects
# Loaded 88 JSON Objects
# Loaded 89 JSON Objects
# Loaded 92 JSON Objects
# Loaded 94 JSON Objects
# Loaded 91 JSON Objects
# Loaded 91 JSON Objects
# Loaded 86 JSON Objects
# Loaded 92 JSON Objects
# Loaded 92 JSON Objects
# Loaded 91 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 89 JSON Objects
# Loaded 91 JSON Objects
# Loaded 91 JSON Objects
# Loaded 92 JSON Objects
# Loaded 96 JSON Objects
# Loaded 92 JSON Objects
# Loaded 91 JSON Objects
# Loaded 96 JSON Objects
# Loaded 97 JSON Objects
# Loaded 95 JSON Objects
# Loaded 95 JSON Objects
# Loaded 85 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 96 JSON Objects
# Loaded 93 JSON Objects
# Loaded 87 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 94 JSON Objects
# Loaded 88 JSON Objects
# Loaded 87 JSON Objects
# Loaded 94 JSON Objects
# Loaded 88 JSON Objects
# Loaded 95 JSON Objects
# Loaded 95 JSON Objects
# Loaded 91 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 88 JSON Objects
# Loaded 92 JSON Objects
# Loaded 97 JSON Objects
# Loaded 95 JSON Objects
# Loaded 90 JSON Objects
# Loaded 94 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 92 JSON Objects
# Loaded 86 JSON Objects
# Loaded 91 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 98 JSON Objects
# Loaded 96 JSON Objects
# Loaded 96 JSON Objects
# Loaded 96 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 90 JSON Objects
# Loaded 98 JSON Objects
# Loaded 97 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 97 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 87 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 96 JSON Objects
# Loaded 92 JSON Objects
# Loaded 97 JSON Objects
# Loaded 90 JSON Objects
# Loaded 87 JSON Objects
# Loaded 89 JSON Objects
# Loaded 95 JSON Objects
# Loaded 96 JSON Objects
# Loaded 96 JSON Objects
# Loaded 91 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 89 JSON Objects
# Loaded 92 JSON Objects
# Loaded 94 JSON Objects
# Loaded 88 JSON Objects
# Loaded 96 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 89 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 94 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 90 JSON Objects
# Loaded 94 JSON Objects
# Loaded 92 JSON Objects
# Loaded 98 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 96 JSON Objects
# Loaded 96 JSON Objects
# Loaded 95 JSON Objects
# Loaded 97 JSON Objects
# Loaded 96 JSON Objects
# Loaded 91 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 89 JSON Objects
# Loaded 92 JSON Objects
# Loaded 94 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 91 JSON Objects
# Loaded 90 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 89 JSON Objects
# Loaded 95 JSON Objects
# Loaded 89 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 91 JSON Objects
# Loaded 92 JSON Objects
# Loaded 96 JSON Objects
# Loaded 95 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 91 JSON Objects
# Loaded 93 JSON Objects
# Loaded 89 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 96 JSON Objects
# Loaded 83 JSON Objects
# Loaded 89 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 90 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 91 JSON Objects
# Loaded 94 JSON Objects
# Loaded 89 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 87 JSON Objects
# Loaded 96 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 90 JSON Objects
# Loaded 66 JSON Objects
# Loaded 90 JSON Objects
# Loaded 96 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 92 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 91 JSON Objects
# Loaded 90 JSON Objects
# Loaded 97 JSON Objects
# Loaded 97 JSON Objects
# Loaded 94 JSON Objects
# Loaded 87 JSON Objects
# Loaded 88 JSON Objects
# Loaded 92 JSON Objects
# Loaded 91 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 94 JSON Objects
# Loaded 89 JSON Objects
# Loaded 95 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 91 JSON Objects
# Loaded 90 JSON Objects
# Loaded 94 JSON Objects
# Loaded 91 JSON Objects
# Loaded 89 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 97 JSON Objects
# Loaded 98 JSON Objects
# Loaded 89 JSON Objects
# Loaded 97 JSON Objects
# Loaded 95 JSON Objects
# Loaded 96 JSON Objects
# Loaded 92 JSON Objects
# Loaded 97 JSON Objects
# Loaded 89 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 96 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 91 JSON Objects
# Loaded 94 JSON Objects
# Loaded 89 JSON Objects
# Loaded 93 JSON Objects
# Loaded 91 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 95 JSON Objects
# Loaded 91 JSON Objects
# Loaded 93 JSON Objects
# Loaded 89 JSON Objects
# Loaded 93 JSON Objects
# Loaded 90 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 96 JSON Objects
# Loaded 96 JSON Objects
# Loaded 96 JSON Objects
# Loaded 96 JSON Objects
# Loaded 90 JSON Objects
# Loaded 94 JSON Objects
# Loaded 97 JSON Objects
# Loaded 93 JSON Objects
# Loaded 90 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 91 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 90 JSON Objects
# Loaded 91 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 98 JSON Objects
# Loaded 95 JSON Objects
# Loaded 98 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 89 JSON Objects
# Loaded 98 JSON Objects
# Loaded 90 JSON Objects
# Loaded 89 JSON Objects
# Loaded 95 JSON Objects
# Loaded 95 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 89 JSON Objects
# Loaded 93 JSON Objects
# Loaded 96 JSON Objects
# Loaded 96 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 98 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 91 JSON Objects
# Loaded 95 JSON Objects
# Loaded 90 JSON Objects
# Loaded 91 JSON Objects
# Loaded 95 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 97 JSON Objects
# Loaded 95 JSON Objects
# Loaded 99 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 90 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 89 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 91 JSON Objects
# Loaded 96 JSON Objects
# Loaded 93 JSON Objects
# Loaded 96 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 88 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 88 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 99 JSON Objects
# Loaded 95 JSON Objects
# Loaded 97 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 98 JSON Objects
# Loaded 94 JSON Objects
# Loaded 93 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 89 JSON Objects
# Loaded 92 JSON Objects
# Loaded 92 JSON Objects
# Loaded 90 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 97 JSON Objects
# Loaded 96 JSON Objects
# Loaded 92 JSON Objects
# Loaded 87 JSON Objects
# Loaded 87 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 91 JSON Objects
# Loaded 96 JSON Objects
# Loaded 96 JSON Objects
# Loaded 95 JSON Objects
# Loaded 100 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 89 JSON Objects
# Loaded 89 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 96 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 89 JSON Objects
# Loaded 98 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 92 JSON Objects
# Loaded 91 JSON Objects
# Loaded 89 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 95 JSON Objects
# Loaded 97 JSON Objects
# Loaded 97 JSON Objects
# Loaded 95 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 88 JSON Objects
# Loaded 97 JSON Objects
# Loaded 95 JSON Objects
# Loaded 90 JSON Objects
# Loaded 95 JSON Objects
# Loaded 98 JSON Objects
# Loaded 93 JSON Objects
# Loaded 97 JSON Objects
# Loaded 98 JSON Objects
# Loaded 92 JSON Objects
# Loaded 96 JSON Objects
# Loaded 97 JSON Objects
# Loaded 91 JSON Objects
# Loaded 86 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 90 JSON Objects
# Loaded 91 JSON Objects
# Loaded 96 JSON Objects
# Loaded 91 JSON Objects
# Loaded 93 JSON Objects
# Loaded 91 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 97 JSON Objects
# Loaded 90 JSON Objects
# Loaded 92 JSON Objects
# Loaded 88 JSON Objects
# Loaded 95 JSON Objects
# Loaded 89 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 91 JSON Objects
# Loaded 94 JSON Objects
# Loaded 88 JSON Objects
# Loaded 93 JSON Objects
# Loaded 86 JSON Objects
# Loaded 92 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 96 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 91 JSON Objects
# Loaded 97 JSON Objects
# Loaded 95 JSON Objects
# Loaded 91 JSON Objects
# Loaded 94 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 96 JSON Objects
# Loaded 91 JSON Objects
# Loaded 90 JSON Objects
# Loaded 87 JSON Objects
# Loaded 94 JSON Objects
# Loaded 84 JSON Objects
# Loaded 94 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 93 JSON Objects
# Loaded 90 JSON Objects
# Loaded 92 JSON Objects
# Loaded 96 JSON Objects
# Loaded 91 JSON Objects
# Loaded 93 JSON Objects
# Loaded 98 JSON Objects
# Loaded 89 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 96 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 94 JSON Objects
# Loaded 92 JSON Objects
# Loaded 91 JSON Objects
# Loaded 89 JSON Objects
# Loaded 91 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 90 JSON Objects
# Loaded 92 JSON Objects
# Loaded 94 JSON Objects
# Loaded 96 JSON Objects
# Loaded 93 JSON Objects
# Loaded 88 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 94 JSON Objects
# Loaded 90 JSON Objects
# Loaded 95 JSON Objects
# Loaded 99 JSON Objects
# Loaded 94 JSON Objects
# Loaded 90 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 92 JSON Objects
# Loaded 89 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 95 JSON Objects
# Loaded 88 JSON Objects
# Loaded 89 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 92 JSON Objects
# Loaded 96 JSON Objects
# Loaded 95 JSON Objects
# Loaded 89 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 94 JSON Objects
# Loaded 91 JSON Objects
# Loaded 91 JSON Objects
# Loaded 95 JSON Objects
# Loaded 96 JSON Objects
# Loaded 93 JSON Objects
# Loaded 96 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 97 JSON Objects
# Loaded 90 JSON Objects
# Loaded 90 JSON Objects
# Loaded 96 JSON Objects
# Loaded 93 JSON Objects
# Loaded 94 JSON Objects
# Loaded 90 JSON Objects
# Loaded 92 JSON Objects
# Loaded 92 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 91 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 97 JSON Objects
# Loaded 95 JSON Objects
# Loaded 88 JSON Objects
# Loaded 92 JSON Objects
# Loaded 96 JSON Objects
# Loaded 91 JSON Objects
# Loaded 93 JSON Objects
# Loaded 91 JSON Objects
# Loaded 96 JSON Objects
# Loaded 98 JSON Objects
# Loaded 92 JSON Objects
# Loaded 91 JSON Objects
# Loaded 95 JSON Objects
# Loaded 90 JSON Objects
# Loaded 89 JSON Objects
# Loaded 95 JSON Objects
# Loaded 94 JSON Objects
# Loaded 96 JSON Objects
# Loaded 95 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 97 JSON Objects
# Loaded 94 JSON Objects
# Loaded 96 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 91 JSON Objects
# Loaded 98 JSON Objects
# Loaded 94 JSON Objects
# Loaded 93 JSON Objects
# Loaded 93 JSON Objects
# Loaded 99 JSON Objects
# Loaded 91 JSON Objects
# Loaded 94 JSON Objects
# Loaded 91 JSON Objects
# Loaded 97 JSON Objects
# Loaded 96 JSON Objects
# Loaded 97 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 88 JSON Objects
# Loaded 97 JSON Objects
# Loaded 94 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 91 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 96 JSON Objects
# Loaded 90 JSON Objects
# Loaded 94 JSON Objects
# Loaded 95 JSON Objects
# Loaded 93 JSON Objects
# Loaded 92 JSON Objects
# Loaded 92 JSON Objects
# Loaded 85 JSON Objects
# Loaded 91 JSON Objects
# Loaded 92 JSON Objects
# Loaded 84 JSON Objects
# Loaded 92 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 94 JSON Objects
# Loaded 94 JSON Objects
# Loaded 93 JSON Objects
# Loaded 90 JSON Objects
# Loaded 99 JSON Objects
# Loaded 96 JSON Objects
# Loaded 94 JSON Objects
# Loaded 91 JSON Objects
# Loaded 96 JSON Objects
# Loaded 93 JSON Objects
# Loaded 95 JSON Objects
# Loaded 98 JSON Objects
# Loaded 89 JSON Objects
# Loaded 91 JSON Objects
# Loaded 93 JSON Objects
# Loaded 88 JSON Objects
# Loaded 95 JSON Objects
# Loaded 92 JSON Objects
# Loaded 94 JSON Objects
# Loaded 91 JSON Objects
# Loaded 90 JSON Objects
# Loaded 95 JSON Objects
# Loaded 88 JSON Objects
# Loaded 90 JSON Objects
# Loaded 88 JSON Objects
# Loaded 93 JSON Objects
# Loaded 97 JSON Objects

# %%
#extracting the columns that I will work with
#did not clean tweets
my_data_dict = defaultdict(list)
missing_retweet = []
for tweet in all_data:
    if 'rt' in tweet['text'].lower()[:4]: #Getting tweets that has RT only
        try:
            my_data_dict['text'].append(tweet['retweeted_status']['text'])
            my_data_dict['oc_id'].append(tweet['retweeted_status']['id'])
            my_data_dict['oc_date'].append(tweet['retweeted_status']['created_at'])
            my_data_dict['rt_id'].append(tweet['id'])
            my_data_dict['rt_date'].append(tweet['created_at'])
        except KeyError as e:
            missing_retweet.append(tweet)
            
print('{} Tweets did not contain retweet status but started with RT'.format(len(missing_retweet)))
tweet_frame = pd.DataFrame(my_data_dict).astype({'oc_date': np.datetime64, 'rt_date': np.datetime64})

#time difference between orginal tweet and first RT
tweet_frame['time_diff'] = tweet_frame[['oc_date', 'rt_date']].apply(lambda 
                                                                     row: row['rt_date'] - row['oc_date'], 
                                                                     axis=1)
tweet_frame.head()
# Out:
# 3410 Tweets did not contain retweet status but started with RT
#                                                 text               oc_id  \
# 0  @danspitz the guildhall in derry city Ireland ...  583736510471659521
# 1  #AutismAcceptance month &amp; support pledge v...  583776584131334144
# 2  I light it up blue. sending 💙 to the families ...  583815315399774208
# 3  We're spreading  #AutismAcceptance on April 2n...  582001852545413120
# 4  #CBS lights the lobby blue for autism awarenes...  583746378003787776
#
#               oc_date               rt_id             rt_date       time_diff
# 0 2015-04-02 21:03:24  583817157894512640 2015-04-03 02:23:51 0 days 05:20:27
# 1 2015-04-02 23:42:38  583816205011550209 2015-04-03 02:20:04 0 days 02:37:26
# 2 2015-04-03 02:16:32  583817138399510529 2015-04-03 02:23:47 0 days 00:07:15
# 3 2015-03-29 02:10:29  583816821008158720 2015-04-03 02:22:31 5 days 00:12:02
# 4 2015-04-02 21:42:36  583816927547654144 2015-04-03 02:22:56 0 days 04:40:20

# %%
#Sentiment analysis with vader
analyser = SentimentIntensityAnalyzer()

def get_sentiment(tweet_t):
    scores = analyser.polarity_scores(tweet_t)
    return scores
    
tweet_frame[['neg', 'neu', 'pos', 'compound']] = tweet_frame.apply(lambda row: pd.Series(get_sentiment(row['text'])), axis=1)
tweet_frame.head()
# Out:
#                                                 text               oc_id  \
# 0  @danspitz the guildhall in derry city Ireland ...  583736510471659521
# 1  #AutismAcceptance month &amp; support pledge v...  583776584131334144
# 2  I light it up blue. sending 💙 to the families ...  583815315399774208
# 3  We're spreading  #AutismAcceptance on April 2n...  582001852545413120
# 4  #CBS lights the lobby blue for autism awarenes...  583746378003787776
#
#               oc_date               rt_id             rt_date       time_diff  \
# 0 2015-04-02 21:03:24  583817157894512640 2015-04-03 02:23:51 0 days 05:20:27
# 1 2015-04-02 23:42:38  583816205011550209 2015-04-03 02:20:04 0 days 02:37:26
# 2 2015-04-03 02:16:32  583817138399510529 2015-04-03 02:23:47 0 days 00:07:15
# 3 2015-03-29 02:10:29  583816821008158720 2015-04-03 02:22:31 5 days 00:12:02
# 4 2015-04-02 21:42:36  583816927547654144 2015-04-03 02:22:56 0 days 04:40:20
#
#    neg    neu    pos  compound
# 0  0.0  1.000  0.000    0.0000
# 1  0.0  0.751  0.249    0.4574
# 2  0.0  0.845  0.155    0.5106
# 3  0.0  1.000  0.000    0.0000
# 4  0.0  0.896  0.104    0.1007

# %%
tweet_frame.groupby(['time_diff']).max()
# Out:
#                                                                  text  \
# time_diff
# 0 days 00:00:00     Whitley has Autism by Teresa L Greenway #autis...
# 0 days 00:00:01     Would you like to know more about #teaching ch...
# 0 days 00:00:02     London Personal Trainer. Ex national level 400...
# 0 days 00:00:03     hey I'm gonna be in Los Angeles for a autism a...
# 0 days 00:00:04     “@trishvail: Tomorrow is World Autism Day. Sho...
# 0 days 00:00:05     ⭐️Come hang out for @OhNoAva_tK's Autism Aware...
# 0 days 00:00:06     “@trishvail: Tomorrow is World Autism Day. Sho...
# 0 days 00:00:07     💜 APHS WEARS PURPLE ON WEDNESDAYS 💜 wear purpl...
# 0 days 00:00:08     💜 APHS WEARS PURPLE ON WEDNESDAYS 💜 wear purpl...
# 0 days 00:00:09     💙April is Autism Awareness Month 💙  \nShow you...
# 0 days 00:00:10     “@trishvail: Tomorrow is World Autism Day. Sho...
# 0 days 00:00:11     💙🔦💙🔦💙🔦💙🔦💙🔦💙🔦💙 Light It Up Blue April 2! Autism...
# 0 days 00:00:12     🔵🔵🔵🔵🔵🔵🔵🔵 For Autism Awareness 🔵🔵🔵🔵🔵🔵🔵🔵 http://...
# 0 days 00:00:13     💙💙💙 RT @WPXI: World turns blue for World Autis...
# 0 days 00:00:14     🔵🔵🔵🔵🔵🔵🔵🔵 For Autism Awareness 🔵🔵🔵🔵🔵🔵🔵🔵 http://...
